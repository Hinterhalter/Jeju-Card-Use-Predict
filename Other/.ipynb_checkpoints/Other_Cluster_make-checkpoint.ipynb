# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, matplotlib as mpl, seaborn as sns, warnings

# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family='NanumGothic')
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]

warnings.filterwarnings(action='ignore')

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR, SVR
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
df_raw = pd.read_csv('../data/jeju_data_ver1/201901-202003.csv')

# %%
df_raw.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %% [markdown]
# # 경기 데이터만 추출

# %%
df = df_raw[df_raw['CARD_SIDO_NM']=='경기']

# %%
df.fillna('세종시', inplace=True)

# %%
df.columns
# Out:
# Index(['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM',
#        'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'AMT', 'CNT'],
#       dtype='object')

# %%
df.drop(['CARD_CCG_NM','HOM_SIDO_NM','HOM_CCG_NM'], axis=1, inplace=True)

# %%
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']).sum().reset_index()

# %%
df['CV'] = 0
df.loc[df['REG_YYMM']==202001, 'CV'] = 1
df.loc[df['REG_YYMM']==202002, 'CV'] = 2
df.loc[df['REG_YYMM']==202003, 'CV'] = 3

# %%
gyeongi = df.groupby(['REG_YYMM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC'])['AMT', 'CNT'].sum().reset_index()

# %%
gyeongi['DATE'] = pd.to_datetime(gyeongi['REG_YYMM'], format='%Y%m')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=gyeongi, x='DATE', y='AMT', hue='STD_CLSS_NM')
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title('월별 업종별 카드 사용금액 추이')
# Out:
# Text(0.5, 1.0, '월별 업종별 카드 사용금액 추이')

# %% [markdown]
# # 전월 대비 증감률 생성

# %%
gyeongi_1 = gyeongi.groupby(['REG_YYMM', 'STD_CLSS_NM'])['AMT', 'CNT'].sum().reset_index()

# %%
tmp = gyeongi_1.pivot_table(index='REG_YYMM', columns='STD_CLSS_NM', values='AMT', aggfunc='sum').apply(lambda x: x.diff() / x * 100).fillna(0)
stack_AMT_diff = tmp.stack().reset_index().rename(columns={0:'AMT_diff'})
stack_AMT_diff
# Out:
#      REG_YYMM            STD_CLSS_NM    AMT_diff
# 0      201901             건강보조식품 소매업    0.000000
# 1      201901                골프장 운영업    0.000000
# 2      201901            과실 및 채소 소매업    0.000000
# 3      201901      관광 민예품 및 선물용품 소매업    0.000000
# 4      201901   그외 기타 분류안된 오락관련 서비스업    0.000000
# ..        ...                    ...         ...
# 580    202003  피자 햄버거 샌드위치 및 유사 음식점업    8.027153
# 581    202003                한식 음식점업    0.224283
# 582    202003                    호텔업 -204.104297
# 583    202003          화장품 및 방향제 소매업   -8.275780
# 584    202003               휴양콘도 운영업  -89.276605
#
# [585 rows x 3 columns]

# %%
tmp = gyeongi_1.pivot_table(index='REG_YYMM', columns='STD_CLSS_NM', values='CNT', aggfunc='sum').apply(lambda x: x.diff() / x * 100).fillna(0)
stack_CNT_diff = tmp.stack().reset_index().rename(columns={0:'CNT_diff'})
stack_CNT_diff
# Out:
#      REG_YYMM            STD_CLSS_NM    CNT_diff
# 0      201901             건강보조식품 소매업    0.000000
# 1      201901                골프장 운영업    0.000000
# 2      201901            과실 및 채소 소매업    0.000000
# 3      201901      관광 민예품 및 선물용품 소매업    0.000000
# 4      201901   그외 기타 분류안된 오락관련 서비스업    0.000000
# ..        ...                    ...         ...
# 580    202003  피자 햄버거 샌드위치 및 유사 음식점업    6.957539
# 581    202003                한식 음식점업    0.728593
# 582    202003                    호텔업  -36.206897
# 583    202003          화장품 및 방향제 소매업   -6.990558
# 584    202003               휴양콘도 운영업 -167.407407
#
# [585 rows x 3 columns]

# %%
CLSS_df = pd.merge(stack_AMT_diff, stack_CNT_diff, on=['REG_YYMM', 'STD_CLSS_NM'])
CLSS_df = CLSS_df[CLSS_df['REG_YYMM'].isin([202003])].groupby(['STD_CLSS_NM'])['AMT_diff','CNT_diff'].sum()
CLSS_df
# Out:
#                          AMT_diff    CNT_diff
# STD_CLSS_NM
# 건강보조식품 소매업              12.089768   15.140821
# 골프장 운영업                 72.541366   65.212301
# 과실 및 채소 소매업             23.753341   25.907692
# 관광 민예품 및 선물용품 소매업      -25.149650   -6.724512
# 그외 기타 분류안된 오락관련 서비스업     0.000000    0.000000
# 그외 기타 스포츠시설 운영업       -186.097224 -353.809524
# 그외 기타 종합 소매업            19.747597   19.918370
# 기타 대형 종합 소매업            10.429617    7.111579
# 기타 수상오락 서비스업            32.244057   29.981025
# 기타 외국식 음식점업             -4.108752   -4.657245
# 기타 주점업                  -9.392925   -8.438361
# 기타음식료품위주종합소매업           24.011473   22.598935
# 내항 여객 운송업                0.000000    0.000000
# 마사지업                   -44.059754  -44.000000
# 버스 운송업                -103.875872  -77.305867
# 비알콜 음료점업                 6.255114    6.991012
# 빵 및 과자류 소매업             11.960509   11.930421
# 서양식 음식점업                 0.492306    2.626516
# 수산물 소매업                 15.728014   27.083939
# 슈퍼마켓                    15.952387   14.310670
# 스포츠 및 레크레이션 용품 임대업      23.204136   26.543905
# 여관업                     -5.811333   -0.818930
# 여행사업                    -9.522944   -9.337349
# 욕탕업                    -35.112977  -31.827439
# 육류 소매업                  23.047442   20.828662
# 일반유흥 주점업               -18.256682  -17.885309
# 일식 음식점업                 -2.492261   -1.604734
# 자동차 임대업                  1.283668    2.213667
# 전시 및 행사 대행업             32.733309   51.123994
# 중식 음식점업                 -0.113022   -0.520934
# 차량용 가스 충전업               2.910986    2.489412
# 차량용 주유소 운영업              0.264371    3.308151
# 체인화 편의점                  7.297666    5.059160
# 택시 운송업                 -16.599356  -16.014937
# 피자 햄버거 샌드위치 및 유사 음식점업    8.027153    6.957539
# 한식 음식점업                  0.224283    0.728593
# 호텔업                   -204.104297  -36.206897
# 화장품 및 방향제 소매업           -8.275780   -6.990558
# 휴양콘도 운영업               -89.276605 -167.407407

# %% [markdown]
# # 군집분석

# %%
CLSS_df.reset_index(inplace=True)

# %%
cl_df = CLSS_df[['AMT_diff', 'CNT_diff']]
cl_df.tail()
# Out:
#       AMT_diff    CNT_diff
# 34    8.027153    6.957539
# 35    0.224283    0.728593
# 36 -204.104297  -36.206897
# 37   -8.275780   -6.990558
# 38  -89.276605 -167.407407

# %% [markdown]
# #### 표준화 및 역할 정의

# %%
X_list = list(cl_df.columns)
# 데이터 표준화
scaler = StandardScaler()
new_df_x = scaler.fit_transform(cl_df[X_list])

# %% [markdown]
# ## k-평균 군집분석

# %% [markdown]
# #### 군집 개수 찾기 : 각 데이터로부터 가장 가까운 군집 중심점까지의 거리 제곱합

# %%
# 최대 군집 생성 개수
n_iter_cluster = 5
cluster_range = [i+1 for i in range(n_iter_cluster)]
clus_error = []
for v_n_clus in cluster_range : 
    clus = KMeans(v_n_clus)
    clus.fit(new_df_x)
    # 각 데이터로 부터 가장 가까운 군집 중심점까지 거리 제곱합
    clus_error.append(clus.inertia_)
ds_error = pd.DataFrame({'NumberofCluster' : cluster_range,
                        'Error' : clus_error})
ds_error
# Out:
#    NumberofCluster      Error
# 0                1  78.000000
# 1                2  25.990386
# 2                3  13.677827
# 3                4   8.885751
# 4                5   4.935766

# %% [markdown]
# #### 4-2) 군집별 군집 중시점까지 거리 제곱합 시각화

# %%
plt.figure(figsize = (10,10))
plt.plot(ds_error['NumberofCluster'], ds_error['Error'])
plt.title("Sum of squared distance")
plt.xlabel('Cluster')
plt.ylabel('Sum of squared distance')
# Out:
# Text(0, 0.5, 'Sum of squared distance')

# %% [markdown]
# #### 4-3) k-평균 군집 번호 생성

# %%
clus = KMeans(n_iter_cluster)
clus.fit(new_df_x)
cluster_kmeans = [i+1 for i in clus.labels_]
CLSS_df['ClusterKmeans'] = cluster_kmeans
CLSS_df.head()
# Out:
#             STD_CLSS_NM   AMT_diff   CNT_diff  ClusterKmeans
# 0            건강보조식품 소매업  12.089768  15.140821              4
# 1               골프장 운영업  72.541366  65.212301              4
# 2           과실 및 채소 소매업  23.753341  25.907692              4
# 3     관광 민예품 및 선물용품 소매업 -25.149650  -6.724512              1
# 4  그외 기타 분류안된 오락관련 서비스업   0.000000   0.000000              1

# %% [markdown]
# #### 4-4) k-평균 군집별 데이터 요약

# %%
ds_summary_km = CLSS_df.groupby("ClusterKmeans").agg(['min','mean','max'])
level0 = ds_summary_km.columns.get_level_values(0)
level1 = ds_summary_km.columns.get_level_values(1)
ds_summary_km.columns = level0 + '_' + level1
ds_summary_km.reset_index(inplace = True)
ds_summary_km.round(3)
# Out:
#    ClusterKmeans  AMT_diff_min  AMT_diff_mean  AMT_diff_max  CNT_diff_min  \
# 0              1       -44.060         -6.161        10.430       -44.000
# 1              2      -186.097       -186.097      -186.097      -353.810
# 2              3      -103.876        -96.576       -89.277      -167.407
# 3              4        11.961         25.584        72.541        11.930
# 4              5      -204.104       -204.104      -204.104       -36.207
#
#    CNT_diff_mean  CNT_diff_max
# 0         -4.841         7.112
# 1       -353.810      -353.810
# 2       -122.357       -77.306
# 3         27.548        65.212
# 4        -36.207       -36.207

# %%
CLSS_df[CLSS_df['ClusterKmeans']==1].sort_values(by='AMT_diff',ascending=False)
# Out:
#               STD_CLSS_NM   AMT_diff   CNT_diff  ClusterKmeans
# 7            기타 대형 종합 소매업  10.429617   7.111579              1
# 34  피자 햄버거 샌드위치 및 유사 음식점업   8.027153   6.957539              1
# 32                체인화 편의점   7.297666   5.059160              1
# 15               비알콜 음료점업   6.255114   6.991012              1
# 30             차량용 가스 충전업   2.910986   2.489412              1
# 27                자동차 임대업   1.283668   2.213667              1
# 17               서양식 음식점업   0.492306   2.626516              1
# 31            차량용 주유소 운영업   0.264371   3.308151              1
# 35                한식 음식점업   0.224283   0.728593              1
# 12              내항 여객 운송업   0.000000   0.000000              1
# 4    그외 기타 분류안된 오락관련 서비스업   0.000000   0.000000              1
# 29                중식 음식점업  -0.113022  -0.520934              1
# 26                일식 음식점업  -2.492261  -1.604734              1
# 9             기타 외국식 음식점업  -4.108752  -4.657245              1
# 21                    여관업  -5.811333  -0.818930              1
# 37          화장품 및 방향제 소매업  -8.275780  -6.990558              1
# 10                 기타 주점업  -9.392925  -8.438361              1
# 22                   여행사업  -9.522944  -9.337349              1
# 33                 택시 운송업 -16.599356 -16.014937              1
# 25               일반유흥 주점업 -18.256682 -17.885309              1
# 3       관광 민예품 및 선물용품 소매업 -25.149650  -6.724512              1
# 23                    욕탕업 -35.112977 -31.827439              1
# 13                   마사지업 -44.059754 -44.000000              1

# %%
CLSS_df[CLSS_df['ClusterKmeans']==2].sort_values(by='AMT_diff',ascending=False)
# Out:
#        STD_CLSS_NM    AMT_diff    CNT_diff  ClusterKmeans
# 5  그외 기타 스포츠시설 운영업 -186.097224 -353.809524              2

# %%
CLSS_df[CLSS_df['ClusterKmeans']==3].sort_values(by='AMT_diff',ascending=False)
# Out:
#    STD_CLSS_NM    AMT_diff    CNT_diff  ClusterKmeans
# 38    휴양콘도 운영업  -89.276605 -167.407407              3
# 14      버스 운송업 -103.875872  -77.305867              3

# %%
CLSS_df[CLSS_df['ClusterKmeans']==4].sort_values(by='AMT_diff',ascending=False)
# Out:
#            STD_CLSS_NM   AMT_diff   CNT_diff  ClusterKmeans
# 1              골프장 운영업  72.541366  65.212301              4
# 28         전시 및 행사 대행업  32.733309  51.123994              4
# 8         기타 수상오락 서비스업  32.244057  29.981025              4
# 11       기타음식료품위주종합소매업  24.011473  22.598935              4
# 2          과실 및 채소 소매업  23.753341  25.907692              4
# 20  스포츠 및 레크레이션 용품 임대업  23.204136  26.543905              4
# 24              육류 소매업  23.047442  20.828662              4
# 6         그외 기타 종합 소매업  19.747597  19.918370              4
# 19                슈퍼마켓  15.952387  14.310670              4
# 18             수산물 소매업  15.728014  27.083939              4
# 0           건강보조식품 소매업  12.089768  15.140821              4
# 16         빵 및 과자류 소매업  11.960509  11.930421              4

# %%
CLSS_df[CLSS_df['ClusterKmeans']==5].sort_values(by='AMT_diff',ascending=False)
# Out:
#    STD_CLSS_NM    AMT_diff   CNT_diff  ClusterKmeans
# 36         호텔업 -204.104297 -36.206897              5

# %%
clss_dict = dict()
for i in range(n_iter_cluster):
    clss_dict[i] = list(CLSS_df[CLSS_df['ClusterKmeans']==i+1]['STD_CLSS_NM'].values)

# %%
CLSS_df.groupby('ClusterKmeans')['AMT_diff'].agg(['mean','median', 'min', 'max']).plot(kind='bar')

# %%
cl1 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[0])]
cl2 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[1])]
cl3 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[2])]
cl4 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[3])]
cl5 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[4])]

# %%
cl1.head()
# Out:
#     REG_YYMM CARD_SIDO_NM        STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  \
# 74    201901           경기  관광 민예품 및 선물용품 소매업  10s            2    1
# 75    201901           경기  관광 민예품 및 선물용품 소매업  20s            1    1
# 76    201901           경기  관광 민예품 및 선물용품 소매업  20s            2    1
# 77    201901           경기  관광 민예품 및 선물용품 소매업  20s            2    2
# 78    201901           경기  관광 민예품 및 선물용품 소매업  30s            1    2
#
#     CSTMR_CNT       AMT   CNT  CV
# 74          4     24500     4   0
# 75       2276  57097620  3488   0
# 76        144   2105700   166   0
# 77         21    229200    24   0
# 78        109   3165300   132   0

# %%
cl1.head()
# Out:
#      REG_YYMM CARD_SIDO_NM STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT  \
# 590    201901           제주   정기 항공 운송업  20s            1    1       1745
# 591    201901           제주   정기 항공 운송업  20s            1    2        134
# 592    201901           제주   정기 항공 운송업  20s            2    1       2250
# 593    201901           제주   정기 항공 운송업  20s            2    2        309
# 594    201901           제주   정기 항공 운송업  30s            1    1        254
#
#            AMT   CNT  CV
# 590  316307962  1728   0
# 591   26026742   144   0
# 592  395638789  2293   0
# 593   53189601   295   0
# 594   49299528   268   0

# %%
cl1.to_csv('../Gyeongi/cl1.csv', index=False, encoding='utf-8-sig')
cl2.to_csv('../Gyeongi/cl2.csv', index=False, encoding='utf-8-sig')
cl3.to_csv('../Gyeongi/cl3.csv', index=False, encoding='utf-8-sig')
cl4.to_csv('../Gyeongi/cl4.csv', index=False, encoding='utf-8-sig')
cl5.to_csv('../Gyeongi/cl5.csv', index=False, encoding='utf-8-sig')
