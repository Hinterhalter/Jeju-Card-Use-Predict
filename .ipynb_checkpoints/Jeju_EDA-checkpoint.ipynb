# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family='NanumGothic')
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]

import warnings
warnings.filterwarnings(action='ignore')

# %%
raw_df = pd.read_csv("./data/jeju_data_ver1/201901-202003.csv")

# %%
raw_df.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %%
raw_df.describe()
# Out:
#            REG_YYMM   SEX_CTGO_CD           FLC     CSTMR_CNT           AMT  \
# count  2.469779e+07  2.469779e+07  2.469779e+07  2.469779e+07  2.469779e+07
# mean   2.019231e+05  1.412645e+00  2.804429e+00  6.196855e+01  2.441353e+06
# std    3.619561e+01  4.923099e-01  1.375455e+00  3.559175e+02  1.726096e+07
# min    2.019010e+05  1.000000e+00  1.000000e+00  3.000000e+00  2.000000e+01
# 25%    2.019040e+05  1.000000e+00  2.000000e+00  4.000000e+00  9.020000e+04
# 50%    2.019080e+05  1.000000e+00  3.000000e+00  8.000000e+00  2.526800e+05
# 75%    2.019110e+05  2.000000e+00  4.000000e+00  2.400000e+01  8.433372e+05
# max    2.020030e+05  2.000000e+00  5.000000e+00  3.281300e+04  2.349524e+09
#
#                 CNT
# count  2.469779e+07
# mean   1.260450e+02
# std    9.669387e+02
# min    1.000000e+00
# 25%    5.000000e+00
# 50%    1.200000e+01
# 75%    4.000000e+01
# max    1.203570e+05

# %%
raw_df.isnull().sum()
# Out:
# REG_YYMM             0
# CARD_SIDO_NM         0
# CARD_CCG_NM      87213
# STD_CLSS_NM          0
# HOM_SIDO_NM          0
# HOM_CCG_NM      147787
# AGE                  0
# SEX_CTGO_CD          0
# FLC                  0
# CSTMR_CNT            0
# AMT                  0
# CNT                  0
# dtype: int64

# %%
# 결측치 시각화
x = raw_df.columns
y = raw_df.isnull().sum()

plt.figure(figsize=(20,7))
sns.set()
sns.barplot(x,y)
ax = plt.gca()
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
           height + 2,
           int(height),
           fontsize=14,
           ha='center',
           va='bottom')
sns.set(font_scale = 1.5)
ax.set_xlabel("Data Attributes")
ax.set_ylabel("count of missing records for each attribute")
plt.xticks(rotation=90)
plt.show()

# %%
ax.patches

# %%
for f in raw_df.columns:
    na = raw_df[f].isnull().sum()
    print(f, "->", "Missing values:", na, "Percentage:", na/len(raw_df)*100)
# Out:
# REG_YYMM -> Missing values: 0 Percentage: 0.0
# CARD_SIDO_NM -> Missing values: 0 Percentage: 0.0
# CARD_CCG_NM -> Missing values: 87213 Percentage: 0.3531206352373524
# STD_CLSS_NM -> Missing values: 0 Percentage: 0.0
# HOM_SIDO_NM -> Missing values: 0 Percentage: 0.0
# HOM_CCG_NM -> Missing values: 147787 Percentage: 0.5983814261614966
# AGE -> Missing values: 0 Percentage: 0.0
# SEX_CTGO_CD -> Missing values: 0 Percentage: 0.0
# FLC -> Missing values: 0 Percentage: 0.0
# CSTMR_CNT -> Missing values: 0 Percentage: 0.0
# AMT -> Missing values: 0 Percentage: 0.0
# CNT -> Missing values: 0 Percentage: 0.0

# %%
raw_df.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %%
df = raw_df

# %%
df.boxplot(column = 'AMT', by = ["REG_YYMM"], figsize=(20,5))

# %%
df.boxplot(column = 'AMT', by = ["CARD_SIDO_NM"], figsize=(20,5))

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x = 'REG_YYMM',
           y = 'AMT',
           hue = 'CARD_SIDO_NM', # 그룹바이의 역할
           data = df,
           linewidth=0.5,
           whis = 3)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,8))
df.groupby(['REG_YYMM'])[['CNT']].sum().plot(kind='bar', ax=ax[0,0], color=color_pal[0])
ax[0,0].set_title('월별 사용 건수')
df.groupby(['REG_YYMM'])[['AMT']].sum().plot(kind='bar', ax=ax[0,1], color=color_pal[1])
ax[0,1].set_title('월별 사용 금액')
df[df['CARD_SIDO_NM']=='제주'].groupby(['REG_YYMM'])[['CNT']].sum().plot(kind='bar', ax=ax[1,0], color=color_pal[2])
ax[1,0].set_title('제주도 월별 사용 건수')
df[df['CARD_SIDO_NM']=='제주'].groupby(['REG_YYMM'])[['AMT']].sum().plot(kind='bar', ax=ax[1,1], color=color_pal[3])
ax[1,1].set_title('제주도 월별 사용 금액')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.6)

# %%
grouped_df = df.groupby(['REG_YYMM', 'STD_CLSS_NM'])[['AMT']].sum()

# %%
df_count
# Out:
# REG_YYMM  STD_CLSS_NM
# 201901    건강보조식품 소매업                 6014
#           골프장 운영업                    8569
#           과실 및 채소 소매업               32830
#           관광 민예품 및 선물용품 소매업          4933
#           그외 기타 분류안된 오락관련 서비스업          6
#                                     ...
# 202003    피자 햄버거 샌드위치 및 유사 음식점업     67596
#           한식 음식점업                  177198
#           호텔업                        4601
#           화장품 및 방향제 소매업             18218
#           휴양콘도 운영업                   2006
# Name: AMT, Length: 615, dtype: int64

# %%
def pie_chart(data):
    data_count = data.groupby(['STD_CLSS_NM'])['AMT'].size
    data_count.plot.pie(y='AMT', autopct = "%.1f%%")

# %%
pie_chart(df[df['REG_YYMM']==202001])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-7885d591c4ca> in <module>
# ----> 1 pie_chart(df[df['REG_YYMM']==202001])
#
# <ipython-input-66-3ab67999dd9c> in pie_chart(data)
#       1 def pie_chart(data):
#       2     data_count = data.groupby(['STD_CLSS_NM'])['AMT'].size
# ----> 3     return data_count.plot.pie(y='AMT', autopct = "%.1f%%")
#
# AttributeError: 'function' object has no attribute 'plot'

# %%
df_count = df.groupby(['REG_YYMM', 'STD_CLSS_NM'])['AMT'].size()
df_count.plot.pie(figsize = (6,6), x='REG_YYMM', y='AMT', autopct = "%.1f%%")

# %% [markdown]
# #
