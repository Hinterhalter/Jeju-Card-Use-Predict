# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, matplotlib as mpl, seaborn as sns, warnings

# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family='NanumGothic')
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]

warnings.filterwarnings(action='ignore')

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR, SVR
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
df_raw = pd.read_csv('../data/jeju_data_ver1/201901-202003.csv')

# %%
df_raw.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %% [markdown]
# # 서울 데이터만 추출

# %%
df = df_raw[df_raw['CARD_SIDO_NM']=='서울']

# %%
df.fillna('세종시', inplace=True)

# %%
df.columns
# Out:
# Index(['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM',
#        'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'AMT', 'CNT'],
#       dtype='object')

# %%
df.drop(['CARD_CCG_NM','HOM_SIDO_NM','HOM_CCG_NM'], axis=1, inplace=True)

# %%
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']).sum().reset_index()

# %%
df['CV'] = 0
df.loc[df['REG_YYMM']==202001, 'CV'] = 1
df.loc[df['REG_YYMM']==202002, 'CV'] = 2
df.loc[df['REG_YYMM']==202003, 'CV'] = 3

# %%
seoul = df.groupby(['REG_YYMM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC'])['AMT', 'CNT'].sum().reset_index()

# %%
seoul['DATE'] = pd.to_datetime(seoul['REG_YYMM'], format='%Y%m')

# %%
# plt.figure(figsize=(20,10))
# sns.lineplot(data=seoul, x='DATE', y='AMT', hue='STD_CLSS_NM')
# plt.legend(bbox_to_anchor=(1.1, 1.05))
# plt.title('월별 업종별 카드 사용금액 추이')

# %% [markdown]
# # 전월 대비 증감률 생성

# %%
seoul_1 = seoul.groupby(['REG_YYMM', 'STD_CLSS_NM'])['AMT', 'CNT'].sum().reset_index()

# %%
tmp = seoul_1.pivot_table(index='REG_YYMM', columns='STD_CLSS_NM', values='AMT', aggfunc='sum').apply(lambda x: x.diff() / x * 100).fillna(0)
stack_AMT_diff = tmp.stack().reset_index().rename(columns={0:'AMT_diff'})
stack_AMT_diff
# Out:
#      REG_YYMM            STD_CLSS_NM   AMT_diff
# 0      201901             건강보조식품 소매업   0.000000
# 1      201901                골프장 운영업   0.000000
# 2      201901            과실 및 채소 소매업   0.000000
# 3      201901      관광 민예품 및 선물용품 소매업   0.000000
# 4      201901        그외 기타 스포츠시설 운영업   0.000000
# ..        ...                    ...        ...
# 580    202003                 택시 운송업 -13.242170
# 581    202003  피자 햄버거 샌드위치 및 유사 음식점업   4.692429
# 582    202003                한식 음식점업 -11.843996
# 583    202003                    호텔업 -95.740420
# 584    202003          화장품 및 방향제 소매업 -12.336805
#
# [585 rows x 3 columns]

# %%
tmp = seoul_1.pivot_table(index='REG_YYMM', columns='STD_CLSS_NM', values='CNT', aggfunc='sum').apply(lambda x: x.diff() / x * 100).fillna(0)
stack_CNT_diff = tmp.stack().reset_index().rename(columns={0:'CNT_diff'})
stack_CNT_diff
# Out:
#      REG_YYMM            STD_CLSS_NM   CNT_diff
# 0      201901             건강보조식품 소매업   0.000000
# 1      201901                골프장 운영업   0.000000
# 2      201901            과실 및 채소 소매업   0.000000
# 3      201901      관광 민예품 및 선물용품 소매업   0.000000
# 4      201901        그외 기타 스포츠시설 운영업   0.000000
# ..        ...                    ...        ...
# 580    202003                 택시 운송업 -12.964278
# 581    202003  피자 햄버거 샌드위치 및 유사 음식점업   2.109133
# 582    202003                한식 음식점업  -9.592622
# 583    202003                    호텔업 -39.421600
# 584    202003          화장품 및 방향제 소매업 -15.909911
#
# [585 rows x 3 columns]

# %%
CLSS_df = pd.merge(stack_AMT_diff, stack_CNT_diff, on=['REG_YYMM', 'STD_CLSS_NM'])
CLSS_df = CLSS_df[CLSS_df['REG_YYMM'].isin([202003])].groupby(['STD_CLSS_NM'])['AMT_diff','CNT_diff'].sum()
CLSS_df
# Out:
#                           AMT_diff     CNT_diff
# STD_CLSS_NM
# 건강보조식품 소매업               11.121835    10.883847
# 골프장 운영업                  46.433002    38.450570
# 과실 및 채소 소매업              18.137205    28.321786
# 관광 민예품 및 선물용품 소매업       -75.833473  -100.225225
# 그외 기타 스포츠시설 운영업        -106.397394  -166.473988
# 그외 기타 종합 소매업              9.674204     9.555282
# 기타 대형 종합 소매업              8.142938     5.456242
# 기타 수상오락 서비스업             14.284628    -0.757576
# 기타 외국식 음식점업             -15.043848   -13.931908
# 기타 주점업                  -14.180826   -13.717681
# 기타음식료품위주종합소매업             3.779950     8.151016
# 내항 여객 운송업                 5.923414    16.912145
# 마사지업                    -30.875119   -18.675497
# 면세점                   -1345.002480 -1191.304348
# 버스 운송업                  -95.329160   -80.236449
# 비알콜 음료점업                 -2.955621    -0.834553
# 빵 및 과자류 소매업               5.497425     4.940846
# 서양식 음식점업                -12.682254    -7.150754
# 수산물 소매업                  12.879824    25.982900
# 슈퍼마켓                     13.789914    12.865815
# 스포츠 및 레크레이션 용품 임대업        9.059804    12.806313
# 여관업                     -18.798744    -9.566618
# 여행사업                   -179.649630   -56.491416
# 욕탕업                     -31.146383   -27.569532
# 육류 소매업                   22.353861    21.586843
# 일반유흥 주점업                -46.941971   -44.626316
# 일식 음식점업                  -9.205615    -7.145412
# 자동차 임대업                  -2.568257     2.191558
# 전시 및 행사 대행업             -96.050610   -83.987342
# 정기 항공 운송업              -265.373027   -91.049031
# 중식 음식점업                 -13.560709   -10.664078
# 차량용 가스 충전업               -1.394537     0.444328
# 차량용 주유소 운영업              -3.680233     1.359384
# 체인화 편의점                   1.692528    -1.350023
# 택시 운송업                  -13.242170   -12.964278
# 피자 햄버거 샌드위치 및 유사 음식점업     4.692429     2.109133
# 한식 음식점업                 -11.843996    -9.592622
# 호텔업                     -95.740420   -39.421600
# 화장품 및 방향제 소매업           -12.336805   -15.909911

# %%
CLSS_df[['AMT_diff']].boxplot()

# %%
clss_quan = list(CLSS_df.AMT_diff.quantile([0.25, 0.5, 0.75]))

# %%
clss_quan
# Out:
# [-31.010751137158564, -9.20561490102387, 7.033175885420388]

# %%
CLSS_df['Cluster'] = 0

# %%
#CLSS_df.loc[CLSS_df['AMT_diff'] < clss_quan[0], 'Cluster']=3
# CLSS_df.loc[(CLSS_df['AMT_diff'] >= clss_quan[0]) & (CLSS_df['AMT_diff'] <= clss_quan[1]),'Cluster']=2
CLSS_df.loc[CLSS_df['AMT_diff'] <= clss_quan[1],'Cluster']=2
CLSS_df.loc[CLSS_df['AMT_diff'] > clss_quan[1],'Cluster']=1

# %%
CLSS_df
# Out:
#               STD_CLSS_NM     AMT_diff     CNT_diff  Cluster
# 0              건강보조식품 소매업    11.121835    10.883847        1
# 1                 골프장 운영업    46.433002    38.450570        1
# 2             과실 및 채소 소매업    18.137205    28.321786        1
# 3       관광 민예품 및 선물용품 소매업   -75.833473  -100.225225        2
# 4         그외 기타 스포츠시설 운영업  -106.397394  -166.473988        2
# 5            그외 기타 종합 소매업     9.674204     9.555282        1
# 6            기타 대형 종합 소매업     8.142938     5.456242        1
# 7            기타 수상오락 서비스업    14.284628    -0.757576        1
# 8             기타 외국식 음식점업   -15.043848   -13.931908        2
# 9                  기타 주점업   -14.180826   -13.717681        2
# 10          기타음식료품위주종합소매업     3.779950     8.151016        1
# 11              내항 여객 운송업     5.923414    16.912145        1
# 12                   마사지업   -30.875119   -18.675497        2
# 13                    면세점 -1345.002480 -1191.304348        2
# 14                 버스 운송업   -95.329160   -80.236449        2
# 15               비알콜 음료점업    -2.955621    -0.834553        1
# 16            빵 및 과자류 소매업     5.497425     4.940846        1
# 17               서양식 음식점업   -12.682254    -7.150754        2
# 18                수산물 소매업    12.879824    25.982900        1
# 19                   슈퍼마켓    13.789914    12.865815        1
# 20     스포츠 및 레크레이션 용품 임대업     9.059804    12.806313        1
# 21                    여관업   -18.798744    -9.566618        2
# 22                   여행사업  -179.649630   -56.491416        2
# 23                    욕탕업   -31.146383   -27.569532        2
# 24                 육류 소매업    22.353861    21.586843        1
# 25               일반유흥 주점업   -46.941971   -44.626316        2
# 26                일식 음식점업    -9.205615    -7.145412        2
# 27                자동차 임대업    -2.568257     2.191558        1
# 28            전시 및 행사 대행업   -96.050610   -83.987342        2
# 29              정기 항공 운송업  -265.373027   -91.049031        2
# 30                중식 음식점업   -13.560709   -10.664078        2
# 31             차량용 가스 충전업    -1.394537     0.444328        1
# 32            차량용 주유소 운영업    -3.680233     1.359384        1
# 33                체인화 편의점     1.692528    -1.350023        1
# 34                 택시 운송업   -13.242170   -12.964278        2
# 35  피자 햄버거 샌드위치 및 유사 음식점업     4.692429     2.109133        1
# 36                한식 음식점업   -11.843996    -9.592622        2
# 37                    호텔업   -95.740420   -39.421600        2
# 38          화장품 및 방향제 소매업   -12.336805   -15.909911        2

# %%
CLSS_df[CLSS_df['Cluster']==1].sort_values(by='AMT_diff',ascending=False)
# Out:
#               STD_CLSS_NM   AMT_diff   CNT_diff  Cluster
# 1                 골프장 운영업  46.433002  38.450570        1
# 24                 육류 소매업  22.353861  21.586843        1
# 2             과실 및 채소 소매업  18.137205  28.321786        1
# 7            기타 수상오락 서비스업  14.284628  -0.757576        1
# 19                   슈퍼마켓  13.789914  12.865815        1
# 18                수산물 소매업  12.879824  25.982900        1
# 0              건강보조식품 소매업  11.121835  10.883847        1
# 5            그외 기타 종합 소매업   9.674204   9.555282        1
# 20     스포츠 및 레크레이션 용품 임대업   9.059804  12.806313        1
# 6            기타 대형 종합 소매업   8.142938   5.456242        1
# 11              내항 여객 운송업   5.923414  16.912145        1
# 16            빵 및 과자류 소매업   5.497425   4.940846        1
# 35  피자 햄버거 샌드위치 및 유사 음식점업   4.692429   2.109133        1
# 10          기타음식료품위주종합소매업   3.779950   8.151016        1
# 33                체인화 편의점   1.692528  -1.350023        1
# 31             차량용 가스 충전업  -1.394537   0.444328        1
# 27                자동차 임대업  -2.568257   2.191558        1
# 15               비알콜 음료점업  -2.955621  -0.834553        1
# 32            차량용 주유소 운영업  -3.680233   1.359384        1

# %%
CLSS_df[CLSS_df['Cluster']==2].sort_values(by='AMT_diff',ascending=False)
# Out:
#           STD_CLSS_NM     AMT_diff     CNT_diff  Cluster
# 26            일식 음식점업    -9.205615    -7.145412        2
# 36            한식 음식점업   -11.843996    -9.592622        2
# 38      화장품 및 방향제 소매업   -12.336805   -15.909911        2
# 17           서양식 음식점업   -12.682254    -7.150754        2
# 34             택시 운송업   -13.242170   -12.964278        2
# 30            중식 음식점업   -13.560709   -10.664078        2
# 9              기타 주점업   -14.180826   -13.717681        2
# 8         기타 외국식 음식점업   -15.043848   -13.931908        2
# 21                여관업   -18.798744    -9.566618        2
# 12               마사지업   -30.875119   -18.675497        2
# 23                욕탕업   -31.146383   -27.569532        2
# 25           일반유흥 주점업   -46.941971   -44.626316        2
# 3   관광 민예품 및 선물용품 소매업   -75.833473  -100.225225        2
# 14             버스 운송업   -95.329160   -80.236449        2
# 37                호텔업   -95.740420   -39.421600        2
# 28        전시 및 행사 대행업   -96.050610   -83.987342        2
# 4     그외 기타 스포츠시설 운영업  -106.397394  -166.473988        2
# 22               여행사업  -179.649630   -56.491416        2
# 29          정기 항공 운송업  -265.373027   -91.049031        2
# 13                면세점 -1345.002480 -1191.304348        2

# %%
CLSS_df[CLSS_df['Cluster']==3].sort_values(by='AMT_diff',ascending=False)
# Out:
#                       AMT_diff     CNT_diff  Cluster
# STD_CLSS_NM
# 욕탕업                 -31.146383   -27.569532        3
# 일반유흥 주점업            -46.941971   -44.626316        3
# 관광 민예품 및 선물용품 소매업   -75.833473  -100.225225        3
# 버스 운송업              -95.329160   -80.236449        3
# 호텔업                 -95.740420   -39.421600        3
# 전시 및 행사 대행업         -96.050610   -83.987342        3
# 그외 기타 스포츠시설 운영업    -106.397394  -166.473988        3
# 여행사업               -179.649630   -56.491416        3
# 정기 항공 운송업          -265.373027   -91.049031        3
# 면세점               -1345.002480 -1191.304348        3

# %%
CLSS_df.reset_index(inplace=True)

# %%
clss_dict = dict()
for i in range(2):
    clss_dict[i] = list(CLSS_df[CLSS_df['Cluster']==i+1]['STD_CLSS_NM'].values)

# %%
CLSS_df.groupby('Cluster')['AMT_diff'].agg(['mean','median', 'min', 'max']).plot(kind='bar')

# %%
cl1 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[0])]
cl2 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[1])]
#cl3 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[2])]
# cl4 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[3])]
# cl5 = df[df['STD_CLSS_NM'].map(lambda x: x in clss_dict[4])]

# %%
cl1.head()
# Out:
#    REG_YYMM CARD_SIDO_NM STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT  \
# 0    201901           서울  건강보조식품 소매업  20s            1    1        115
# 1    201901           서울  건강보조식품 소매업  20s            2    1        407
# 2    201901           서울  건강보조식품 소매업  20s            2    2         11
# 3    201901           서울  건강보조식품 소매업  30s            1    1         10
# 4    201901           서울  건강보조식품 소매업  30s            1    2        874
#
#         AMT   CNT  CV
# 0   7809970   140   0
# 1  19074744   516   0
# 2    868200    12   0
# 3   4767250    11   0
# 4  74320644  1045   0

# %%
cl1.head()
# Out:
#    REG_YYMM CARD_SIDO_NM STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT  \
# 0    201901           서울  건강보조식품 소매업  20s            1    1        115
# 1    201901           서울  건강보조식품 소매업  20s            2    1        407
# 2    201901           서울  건강보조식품 소매업  20s            2    2         11
# 3    201901           서울  건강보조식품 소매업  30s            1    1         10
# 4    201901           서울  건강보조식품 소매업  30s            1    2        874
#
#         AMT   CNT  CV
# 0   7809970   140   0
# 1  19074744   516   0
# 2    868200    12   0
# 3   4767250    11   0
# 4  74320644  1045   0

# %%
cl1.to_csv('../Seoul/cl1.csv', index=False, encoding='utf-8-sig')
cl2.to_csv('../Seoul/cl2.csv', index=False, encoding='utf-8-sig')
#cl3.to_csv('../Seoul/cl3.csv', index=False, encoding='utf-8-sig')
# cl4.to_csv('../Seoul/cl4.csv', index=False, encoding='utf-8-sig')
# cl5.to_csv('../Seoul/cl5.csv', index=False, encoding='utf-8-sig')
