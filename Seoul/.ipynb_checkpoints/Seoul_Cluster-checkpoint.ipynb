# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, matplotlib as mpl, seaborn as sns, warnings

# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family='NanumGothic')
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]

warnings.filterwarnings(action='ignore')

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import LinearSVR, SVR
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.cluster import KMeans, DBSCAN
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
df_raw = pd.read_csv('./data/jeju_data_ver1/201901-202003.csv')

# %%
df_raw.head()
# Out:
#    REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4    201901           강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
#
#    SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0            1    1          4   311200    4
# 1            1    2          7  1374500    8
# 2            2    2          6   818700    6
# 3            1    3          4  1717000    5
# 4            1    4          3  1047300    3

# %%
df_raw.STD_CLSS_NM.unique().__len__()
# Out:
# 41

# %%
df_raw.columns
# Out:
# Index(['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM',
#        'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'AMT', 'CNT'],
#       dtype='object')

# %% [markdown]
# #### 1, 2, 3월 데이터만 추출

# %%
df = df_raw[(df_raw['REG_YYMM'] == 202001) | (df_raw['REG_YYMM'] == 202002) | (df_raw['REG_YYMM'] == 202003)]
df.head()
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 20425415    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425416    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425417    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425418    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425419    202001           강원         강릉시  건강보조식품 소매업          강원
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 20425415        강릉시  20s            2    1          3   345000    3
# 20425416        강릉시  30s            1    2          3  1903450    3
# 20425417        강릉시  30s            2    2         14  1520500   15
# 20425418        강릉시  40s            1    3          9  1239200    9
# 20425419        강릉시  40s            1    4          3   606700    4

# %% [markdown]
# #### 서울 데이터만 추출

# %%
df = df[df['CARD_SIDO_NM']=='서울']

# %%
df.fillna('세종시', inplace=True)

# %%
df.columns
# Out:
# Index(['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM',
#        'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'AMT', 'CNT'],
#       dtype='object')

# %%
df.drop(['CARD_CCG_NM','HOM_SIDO_NM','HOM_CCG_NM'], axis=1, inplace=True)

# %%
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']).sum().reset_index()

# %%
def grap_year(data):
    data = str(data)
    return int(data[:4])

def grap_month(data):
    data = str(data)
    return int(data[4:])

def make_season(data):
    if data in [12, 1, 2]:
        return 'Winter'
    elif data in [3, 4, 5]:
        return 'Spring'
    elif data in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

# %%
df['year'] = df['REG_YYMM'].apply(lambda x: grap_year(x))
df['month'] = df['REG_YYMM'].apply(lambda x: grap_month(x))
df = df.drop(['REG_YYMM'], axis=1)
df['Season'] = df['month'].apply(lambda x: make_season(x))

# %%
df.Season.unique()
# Out:
# array(['Winter', 'Spring'], dtype=object)

# %% [markdown]
# # 군집분석

# %%
new_df = df.groupby(['STD_CLSS_NM'])['CSTMR_CNT', 'AMT', 'CNT'].median().reset_index()

cl_df = new_df[['CSTMR_CNT', 'AMT', 'CNT']]
cl_df.tail()
# Out:
#     CSTMR_CNT           AMT       CNT
# 34    57031.5  1.332517e+09  172765.0
# 35    17625.5  2.590352e+08   25989.5
# 36    49342.0  2.203159e+09   82189.0
# 37      697.5  6.914922e+07    1520.0
# 38     2927.5  1.921289e+08    3861.0

# %%
X_list = list(cl_df.columns)
#X_list.remove('AMT')

# %% [markdown]
# #### 표준화 및 역할 정의

# %%
# 데이터 표준화
scaler = StandardScaler()
# 목표변수 y를 trip_total로 설정

new_df_x = scaler.fit_transform(cl_df[X_list])
#new_df_y = scaler.fit_transform(df[['AMT']])

# %% [markdown]
# ## k-평균 군집분석

# %% [markdown]
# #### 군집 개수 찾기 : 각 데이터로부터 가장 가까운 군집 중심점까지의 거리 제곱합

# %%
# 최대 군집 생성 개수
n_iter_cluster = 5
cluster_range = [i+1 for i in range(n_iter_cluster)]
clus_error = []
for v_n_clus in cluster_range : 
    clus = KMeans(v_n_clus)
    clus.fit(new_df_x)
    # 각 데이터로 부터 가장 가까운 군집 중심점까지 거리 제곱합
    clus_error.append(clus.inertia_)
ds_error = pd.DataFrame({'NumberofCluster' : cluster_range,
                        'Error' : clus_error})
ds_error
# Out:
#    NumberofCluster       Error
# 0                1  117.000000
# 1                2   27.373617
# 2                3   16.828606
# 3                4    9.083633
# 4                5    5.968435

# %% [markdown]
# #### 4-2) 군집별 군집 중시점까지 거리 제곱합 시각화

# %%
plt.figure(figsize = (10,10))
plt.plot(ds_error['NumberofCluster'], ds_error['Error'])
plt.title("Sum of squared distance")
plt.xlabel('Cluster')
plt.ylabel('Sum of squared distance')
# Out:
# Text(0, 0.5, 'Sum of squared distance')

# %% [markdown]
# #### 4-3) k-평균 군집 번호 생성

# %%
clus = KMeans(n_iter_cluster)
clus.fit(new_df_x)
cluster_kmeans = [i+1 for i in clus.labels_]
new_df['ClusterKmeans'] = cluster_kmeans
new_df.head()
# Out:
#          STD_CLSS_NM  CSTMR_CNT         AMT     CNT  ClusterKmeans
# 0         건강보조식품 소매업      208.0  17303790.0   253.0              1
# 1            골프장 운영업       39.0   4115700.0    53.0              1
# 2        과실 및 채소 소매업     3270.0  93976075.0  5375.5              1
# 3  관광 민예품 및 선물용품 소매업       45.0   1260150.0    58.0              1
# 4    그외 기타 스포츠시설 운영업       19.5   1751500.0    37.5              1

# %% [markdown]
# #### 4-4) k-평균 군집별 데이터 요약

# %%
ds_summary_km = new_df.groupby("ClusterKmeans").agg(['min','mean','max'])
level0 = ds_summary_km.columns.get_level_values(0)
level1 = ds_summary_km.columns.get_level_values(1)
ds_summary_km.columns = level0 + '_' + level1
ds_summary_km.reset_index(inplace = True)
ds_summary_km.round(3)
# Out:
#    ClusterKmeans  CSTMR_CNT_min  CSTMR_CNT_mean  CSTMR_CNT_max       AMT_min  \
# 0              1           11.0        1842.767         7050.0  3.670000e+05
# 1              2        49342.0       49342.000        49342.0  2.203159e+09
# 2              3        16070.0       23519.625        37034.0  2.400817e+08
# 3              4        47950.0       52490.750        57031.5  1.084157e+09
# 4              5        20650.5       24861.000        29071.5  1.470525e+09
#
#        AMT_mean       AMT_max   CNT_min    CNT_mean   CNT_max
# 0  9.790925e+07  5.940671e+08      13.0    2876.333   12276.0
# 1  2.203159e+09  2.203159e+09   82189.0   82189.000   82189.0
# 2  3.754804e+08  5.634234e+08   25583.0   37873.500   62457.5
# 3  1.208337e+09  1.332517e+09  153060.0  162912.500  172765.0
# 4  1.503299e+09  1.536074e+09   49722.5   69165.750   88609.0

# %%
new_df[new_df['ClusterKmeans']==1].sort_values(by='AMT',ascending=False)
# Out:
#            STD_CLSS_NM  CSTMR_CNT          AMT      CNT  ClusterKmeans
# 5         그외 기타 종합 소매업     5354.0  594067100.0   8975.0              1
# 32         차량용 주유소 운영업     5775.0  323714607.0   8146.0              1
# 10       기타음식료품위주종합소매업     3739.0  232754190.0  12276.0              1
# 30             중식 음식점업     7050.0  229916135.5   9478.0              1
# 26             일식 음식점업     5329.0  219491310.5   6462.5              1
# 24              육류 소매업     5452.0  209031134.5   8430.5              1
# 38       화장품 및 방향제 소매업     2927.5  192128924.0   3861.0              1
# 20  스포츠 및 레크레이션 용품 임대업     1630.5  186387680.0   1912.5              1
# 29           정기 항공 운송업      754.5  133760500.0    719.5              1
# 8          기타 외국식 음식점업     4867.0  118630950.0   5777.0              1
# 2          과실 및 채소 소매업     3270.0   93976075.0   5375.5              1
# 14              버스 운송업     4021.0   78255600.0   6757.0              1
# 37                 호텔업      697.5   69149224.0   1520.0              1
# 18             수산물 소매업      983.5   47904720.0   1362.0              1
# 23                 욕탕업     1520.5   32760450.0   2359.0              1
# 25            일반유흥 주점업      215.0   25967300.0    345.0              1
# 21                 여관업      280.0   24090610.0    422.0              1
# 22                여행사업      130.0   21560772.0    152.0              1
# 9               기타 주점업      148.0   19703504.0    202.0              1
# 0           건강보조식품 소매업      208.0   17303790.0    253.0              1
# 11           내항 여객 운송업      218.0   15758760.0    520.0              1
# 31          차량용 가스 충전업      308.0   15244833.0    446.0              1
# 13                 면세점       58.0   14570305.0     75.0              1
# 27             자동차 임대업       39.0    5773100.0     60.0              1
# 1              골프장 운영업       39.0    4115700.0     53.0              1
# 28         전시 및 행사 대행업      156.0    4022777.5    198.5              1
# 12                마사지업       37.5    3858750.0     43.5              1
# 4      그외 기타 스포츠시설 운영업       19.5    1751500.0     37.5              1
# 3    관광 민예품 및 선물용품 소매업       45.0    1260150.0     58.0              1
# 7         기타 수상오락 서비스업       11.0     367000.0     13.0              1

# %%
new_df[new_df['ClusterKmeans']==2].sort_values(by='AMT',ascending=False)
# Out:
#    STD_CLSS_NM  CSTMR_CNT           AMT      CNT  ClusterKmeans
# 36     한식 음식점업    49342.0  2.203159e+09  82189.0              2

# %%
new_df[new_df['ClusterKmeans']==3].sort_values(by='AMT',ascending=False)
# Out:
#               STD_CLSS_NM  CSTMR_CNT          AMT      CNT  ClusterKmeans
# 17               서양식 음식점업    23349.0  563423444.0  37464.0              3
# 15               비알콜 음료점업    37034.0  439381067.0  62457.5              3
# 35  피자 햄버거 샌드위치 및 유사 음식점업    17625.5  259035201.5  25989.5              3
# 16            빵 및 과자류 소매업    16070.0  240081748.5  25583.0              3

# %%
new_df[new_df['ClusterKmeans']==4].sort_values(by='AMT',ascending=False)
# Out:
#    STD_CLSS_NM  CSTMR_CNT           AMT       CNT  ClusterKmeans
# 34      택시 운송업    57031.5  1.332517e+09  172765.0              4
# 33     체인화 편의점    47950.0  1.084157e+09  153060.0              4

# %%
new_df[new_df['ClusterKmeans']==5].sort_values(by='AMT',ascending=False)
# Out:
#      STD_CLSS_NM  CSTMR_CNT           AMT      CNT  ClusterKmeans
# 6   기타 대형 종합 소매업    20650.5  1.536074e+09  49722.5              5
# 19          슈퍼마켓    29071.5  1.470525e+09  88609.0              5

# %%
tmp = pd.DataFrame(index=['cluster_{}'.format(i+1) for i in range(n_iter_cluster)] , columns=['class'])

# %%
for i in range(n_iter_cluster):
    tmp.iloc[i,0] = new_df[new_df['ClusterKmeans']==i+1]['STD_CLSS_NM'].values

# %%
tmp
# Out:
#                                                        class
# cluster_1  [건강보조식품 소매업, 골프장 운영업, 과실 및 채소 소매업, 관광 민예품 및 선물...
# cluster_2                                          [한식 음식점업]
# cluster_3  [비알콜 음료점업, 빵 및 과자류 소매업, 서양식 음식점업, 피자 햄버거 샌드위치 ...
# cluster_4                                  [체인화 편의점, 택시 운송업]
# cluster_5                               [기타 대형 종합 소매업, 슈퍼마켓]

# %%
# 클러스터 정보 저장
tmp.to_csv('./data/Seoul_class_cluster.txt',index=False)

# %%
new_df.groupby('ClusterKmeans')['AMT'].agg(['mean','median', 'min', 'max']).plot(kind='bar')

# %%
df_raw
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 0           201901           강원         강릉시  건강보조식품 소매업          강원
# 1           201901           강원         강릉시  건강보조식품 소매업          강원
# 2           201901           강원         강릉시  건강보조식품 소매업          강원
# 3           201901           강원         강릉시  건강보조식품 소매업          강원
# 4           201901           강원         강릉시  건강보조식품 소매업          강원
# ...            ...          ...         ...         ...         ...
# 24697787    202003           충북         충주시    휴양콘도 운영업          충북
# 24697788    202003           충북         충주시    휴양콘도 운영업          충북
# 24697789    202003           충북         충주시    휴양콘도 운영업          충북
# 24697790    202003           충북         충주시    휴양콘도 운영업          충북
# 24697791    202003           충북         충주시    휴양콘도 운영업          충북
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0               강릉시  20s            1    1          4   311200    4
# 1               강릉시  30s            1    2          7  1374500    8
# 2               강릉시  30s            2    2          6   818700    6
# 3               강릉시  40s            1    3          4  1717000    5
# 4               강릉시  40s            1    4          3  1047300    3
# ...             ...  ...          ...  ...        ...      ...  ...
# 24697787        충주시  30s            1    2          3    43300    4
# 24697788        충주시  40s            1    3          3    35000    3
# 24697789        충주시  50s            1    4          4   188000    6
# 24697790        충주시  50s            2    4          4    99000    6
# 24697791        충주시  60s            1    5          3   194000    3
#
# [24697792 rows x 12 columns]

# %% [markdown]
# #### 1, 2, 3월 데이터만 추출

# %%
df = df_raw[(df_raw['REG_YYMM'] == 202001) | (df_raw['REG_YYMM'] == 202002) | (df_raw['REG_YYMM'] == 202003)]
df.head()
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 20425415    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425416    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425417    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425418    202001           강원         강릉시  건강보조식품 소매업          강원
# 20425419    202001           강원         강릉시  건강보조식품 소매업          강원
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 20425415        강릉시  20s            2    1          3   345000    3
# 20425416        강릉시  30s            1    2          3  1903450    3
# 20425417        강릉시  30s            2    2         14  1520500   15
# 20425418        강릉시  40s            1    3          9  1239200    9
# 20425419        강릉시  40s            1    4          3   606700    4

# %%
df.fillna('세종시', inplace=True)

# %%
df.columns
# Out:
# Index(['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM',
#        'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'AMT', 'CNT'],
#       dtype='object')

# %%
df.drop(['CARD_CCG_NM','HOM_SIDO_NM','HOM_CCG_NM'], axis=1, inplace=True)

# %%
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']).sum().reset_index()

# %%
df.head()
# Out:
#    REG_YYMM CARD_SIDO_NM STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT  \
# 0    202001           강원  건강보조식품 소매업  20s            1    1          6
# 1    202001           강원  건강보조식품 소매업  20s            2    1         13
# 2    202001           강원  건강보조식품 소매업  30s            1    2         72
# 3    202001           강원  건강보조식품 소매업  30s            2    2         88
# 4    202001           강원  건강보조식품 소매업  40s            1    3         90
#
#         AMT  CNT
# 0    168500    6
# 1    764646   13
# 2  12017410   73
# 3   9867625   89
# 4  10645775   91

# %% [markdown]
# # 군집 데이터 불러오기

# %%
cluster_info = pd.read_csv("./data/class_cluster.txt")

# %%
for i in cluster_info.iloc[0]:
    print(i)
# Out:
# ['관광 민예품 및 선물용품 소매업' '그외 기타 분류안된 오락관련 서비스업' '그외 기타 스포츠시설 운영업'
#  '기타 수상오락 서비스업' '내항 여객 운송업' '여관업' '여행사업' '전시 및 행사 대행업' '휴양콘도 운영업']

# %% [markdown]
# # 1번 군집

# %%
class_list = ['관광 민예품 및 선물용품 소매업', '그외 기타 분류안된 오락관련 서비스업', '그외 기타 스포츠시설 운영업',
 '기타 수상오락 서비스업', '내항 여객 운송업', '여관업', '여행사업', '전시 및 행사 대행업', '휴양콘도 운영업']
len(class_list)
# Out:
# 9

# %%
df = df[df['STD_CLSS_NM'].map(lambda x: x in class_list)]

# %%
df.head()
# Out:
#     REG_YYMM CARD_SIDO_NM        STD_CLSS_NM  AGE  SEX_CTGO_CD  FLC  \
# 62    202001           강원  관광 민예품 및 선물용품 소매업  20s            1    1
# 63    202001           강원  관광 민예품 및 선물용품 소매업  20s            1    2
# 64    202001           강원  관광 민예품 및 선물용품 소매업  20s            2    1
# 65    202001           강원  관광 민예품 및 선물용품 소매업  30s            1    2
# 66    202001           강원  관광 민예품 및 선물용품 소매업  30s            2    2
#
#     CSTMR_CNT      AMT  CNT
# 62        264  3957595  294
# 63          3    33600    3
# 64         83   914200   86
# 65         67  1469800   74
# 66         82  1782700   96

# %%
df.STD_CLSS_NM.unique()
# Out:
# array(['관광 민예품 및 선물용품 소매업', '그외 기타 스포츠시설 운영업', '기타 수상오락 서비스업',
#        '내항 여객 운송업', '여관업', '여행사업', '전시 및 행사 대행업', '휴양콘도 운영업',
#        '그외 기타 분류안된 오락관련 서비스업'], dtype=object)

# %%
def grap_year(data):
    data = str(data)
    return int(data[:4])

def grap_month(data):
    data = str(data)
    return int(data[4:])

# %%
df['year'] = df['REG_YYMM'].apply(lambda x: grap_year(x))
df['month'] = df['REG_YYMM'].apply(lambda x: grap_month(x))
df = df.drop(['REG_YYMM'], axis=1)
